# %%
# SPA: Crear catálogo telco_churn con esquemas bronze, silver, gold, models y volumen bronze.raw
# ENG: Create catalog telco_churn with schemas bronze, silver, gold, models and volume bronze.raw

spark.sql("""
CREATE CATALOG IF NOT EXISTS telco_churn
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS telco_churn.bronze
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS telco_churn.silver
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS telco_churn.gold
""")

spark.sql("""
CREATE SCHEMA IF NOT EXISTS telco_churn.models
""")

spark.sql("""
CREATE VOLUME IF NOT EXISTS telco_churn.bronze.raw
""")
